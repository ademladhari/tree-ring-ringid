# %% [markdown]
# # RingID / Tree-Ring Generation in Google Colab
#
# Clone the repository, install requirements, and run the generation command.

# %% [markdown]
# ## Replace the placeholder repo URL
#
# Set `REPO_URL` to your actual GitHub repository before running the first cell.

# %%
# 1) Clone the repository
from pathlib import Path

REPO_URL = "https://github.com/ademladhari/tree-ring-ringid"  # replace this placeholder
REPO_DIR = Path("tree-ring-ringid")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}
else:
    print(f"Repository already exists at {REPO_DIR}")

# %cd tree-ring-ringid
# Out:
# Cloning into 'tree-ring-ringid'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 72 (delta 0), reused 72 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 18.33 MiB | 47.52 MiB/s, done.
# /content/tree-ring-ringid

# %%
# 2) Install requirements
# !python -m pip install -U pip
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 42.3 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Obtaining file:///content/tree-ring-ringid
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ringid-watermark (pyproject.toml) ... done
#   Created wheel for ringid-watermark: filename=ringid_watermark-0.1.0-0.editable-py3-none-any.whl size=4960 sha256=471146405bd5e56e428931e9c625ff7cc29a765bb170184626306d937bbf4a4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ws_eg8sp/wheels/de/3f/d8/6fb2c7b2b1e13b6b0de9c70e92653c3973d99fa37a6c23f5a2
# Successfully built ringid-watermark
# ...

# %%
# 3) Run generation for 40 images
PROMPT = "a photo of a red bicycle parked beside a brick wall"
OUT_DIR = "batch_run"

# !ringid-generate --prompt "{PROMPT}" --count 40 --out-dir "{OUT_DIR}" --profile tree_ring --model-id runwayml/stable-diffusion-v1-5 --steps 50 --height 512 --width 512 --guidance-scale 7.5 --seed 42

# !ls -lah "{OUT_DIR}"

# %%
# 4) Evaluate the 40 generated images
# !python evaluation/run_pipeline.py --manifest batch_run/manifest.json --out evaluation/results --n-clean 40 --target-fpr 0.01

# !ls -lah evaluation/results
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json: 100% 543/543 [00:00<00:00, 3.42MB/s]
# ...
# Fetching 13 files: 100% 13/13 [00:28<00:00,  2.17s/it]
# Download complete: : 5.16GB [00:28, 211MB/s]
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading pipeline components...:  17% 1/6 [00:00<00:01,  4.18it/s]
# Loading pipeline components...:  33% 2/6 [00:05<00:12,  3.22s/it]
# Loading pipeline components...:  67% 4/6 [00:06<00:03,  1.61s/it]
# Loading pipeline components...:  83% 5/6 [00:07<00:01,  1.16s/it]
#
# ...

# %%
# 5) Run attack evaluation on the same 40-image batch
# !python evaluation/run_attacks_eval.py --manifest batch_run/manifest.json --out evaluation/attack_results --n-clean 40 --max-wm 40 --target-fpr 0.01

# !ls -lah evaluation/attack_results
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading pipeline components...:  17% 1/6 [00:07<00:38,  7.67s/it]
# Loading weights:   0% 0/372 [00:00<?, ?it/s]
# Loading weights:   0% 1/372 [00:00<00:00, 11155.06it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   0% 1/372 [00:00<00:00, 5302.53it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/372 [00:00<00:00, 4657.75it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/372 [00:00<00:00, 4009.85it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %% [markdown]
# ## 5) Run attack evaluation
#
# This writes attack metrics to `evaluation/attack_results/attack_metrics.json` and `evaluation/attack_results/attack_report.md`.
